# %% [markdown]
# # Help Navigate Robots
#
# https://www.kaggle.com/competitions/career-con-2019/overview
# 위의 링크의 데이터셋을 받아 분류를 수행해보자
#
#
# 로봇이 임무를 적절히 수행하기 위해서는 그들의 환경을 잘 인식하는것이 중요한다. 센서 데이터(속도 가속도 등)를 받아, 로봇이 어떤 유형의 지면에 있는지 분류해야한다. 지면 유형은 9가지(카펫, 타일, 콘크리트) 이며, 이를 분류하는 코드를 작성해보자.

# %%
# 데이터 전처리

# %%
# 모델정의 (ML모델이 아닌, 딥러닝 모델로 할것!)

# %%
# 모델 학습

# %%
# 결과 시각화

# %%
# Confusion matrix 출력

# %%
# 결과분석 ( + 성능을 좋게하기위해 어떤 노력을 했는지 작성)
