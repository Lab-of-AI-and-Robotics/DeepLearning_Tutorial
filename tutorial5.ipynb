# %% [markdown]
# # Input image와 비슷한 image를 생성하는 Variational Auto Encoder 구현
#
#
# keyword: variational auto encoder, transpose convolution, latent vector, photometric loss, psnr/ssim/lpips
#
# - 1. cifar10 dataset을 한 폴더에 두고 수행할것 (즉 데이터 로더를 직접 짜야함.)
# - 2. custom dataloader 파이토치 내부함수가 아니라 본인이 직접 짤것.
# - 3. 외부모듈, 함수 사용하여 input image와 output image의 psnr값을 비교해볼것
# - 4. auto encoder와 달리 data agumentation을 진행해볼것

# %%
# 구글 마운트 (직접 data loader를 짜는것이 목표임으로, tutorial1,2와 같이 모듈을 통해 데이터를 불러오지 않아야함. 그래서 구글 드라이브에 cifar10 dataset image를 넣어두고, 코드를 짤것!)
from google.colab import drive
drive.mount('/content/drive')

# %%
# dataset 경로설정, dataloader등 구현
# dataset은 cifar10 폴더 안에, 10개의 class name 폴더가 있고, 각각의 class name 폴더안에 이미지들이 들어가게끔 코드를 구현할것!

# %%
# 데이터 agumentation 진행 (진행한것과 안진행한 모델을 비교할것임)

# %%
# 모델

# %%
# 학습

# %%
# Loss 그래프 시각화 (training, test 셋에 대하여)

# %%
# 생성한 결과 시각화 2가지 비교 (data augmentation 진행한것과 안한것)

# %%
# test 셋에 대하여 생성한 결과 psnr, ssim, lpips 값 비교 (data augmentation 진행한것과 안한것)
